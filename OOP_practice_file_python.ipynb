# %% [markdown]
# # 🚀 Python OOP Beginner Practice
#
# ## **Encapsulation | Inheritance | Polymorphism | Abstraction**
#
# ---
#
# ## 📖 Overview
#
# This notebook is designed to help you practice the fundamental concepts of **Object-Oriented Programming (OOP)** in Python through beginner-friendly exercises. Each section focuses on one of the four core OOP principles and contains practical questions to strengthen your understanding.
#
# ---
#
# ## 🎯 Topics Covered
#
# - 🔒 Encapsulation
# - 👨‍👩‍👦 Inheritance
# - 🔄 Polymorphism
# - 🎭 Abstraction
#
# ---
#
# ## 📂 Notebook Structure
#
# | Section | Concept | Description |
# |---------|---------|-------------|
# | **Section 1** | 🔒 Encapsulation | Private variables, getters, and setters |
# | **Section 2** | 👨‍👩‍👦 Inheritance | Parent and child classes |
# | **Section 3** | 🔄 Polymorphism | Method overriding and dynamic behavior |
# | **Section 4** | 🎭 Abstraction | Abstract classes and abstract methods |
#
# ---
#
# ## 📝 Instructions
#
# - Read each question carefully.
# - Write your solution in the code cell provided below each question.
# - Create classes, objects, constructors, and methods as required.
# - Execute each cell to verify the output.
# - Complete every question in sequence.
#
# ---
#
# ## ✅ Learning Outcomes
#
# After completing this notebook, you will be able to:
#
# - Create classes and objects in Python.
# - Implement encapsulation using private members.
# - Apply inheritance to reuse code.
# - Understand and implement polymorphism.
# - Work with abstract classes and methods.
# - Develop basic object-oriented programs.
#
# ---
#
# > **Language:** Python 3.x
# > **Difficulty:** Beginner
# > **Topics:** Object-Oriented Programming (OOP)
#
# ---

# %% [markdown]
# ---
#
# ## Section 1: Encapsulation Practice
#
# Encapsulation means restricting direct access to some variables inside a class.
# Use double underscore (`__`) to make a variable private.
# Use getter methods to access private variables from outside the class.

# %% [markdown]
# ### Question 1
#
# **Problem Statement:**
# Create a class `Student` with a private variable `__name`.
# Write a getter method `get_name()` that returns the student name.
# Create an object and call the getter method to print the name.
#
# **Hint:** Use `__name` to declare a private variable inside `__init__`.

# %%
# Write your code here
class Student:
    def __init__(self,name):
        self.__name = name

    def getname(self):
        return self.__name

student1 = Student("Sohan")
print(student1.getname())
# Out:
# Sohan

# %% [markdown]
# ### Question 2
#
# **Problem Statement:**
# Create a class `BankAccount` with a private variable `__balance`.
# Set the balance to `5000` in `__init__`.
# Write a getter method `get_balance()` that returns the balance.
# Create an object and print the balance using the getter method.
#
# **Hint:** The private variable cannot be accessed directly from outside the class.

# %%
# Write your code here
class BankAccount:
    def __init__(self,balance):
        self.__balance = balance

    def getbalance(self):
        return self.__balance

bankaccount = BankAccount(120043)
print(bankaccount.getbalance())
# Out:
# 120043

# %% [markdown]
# ### Question 3
#
# **Problem Statement:**
# Create a class `Employee` with two private variables: `__emp_name` and `__salary`.
# Write two getter methods: `get_name()` and `get_salary()`.
# Create an object by passing name and salary as arguments.
# Print both using the getter methods.
#
# **Hint:** Accept both values in `__init__(self, name, salary)`.

# %%
# Write your code here
class Employee:
    def __init__(self,name,salary):
        self.__name = name
        self.__salary = salary

    def getname(self):
        return self.__name

    def getsalary(self):
        return self.__salary

employee = Employee("Virat","4000000")  
print(employee.getsalary())
# Out:
# 4000000

# %% [markdown]
# ### Question 4
#
# **Problem Statement:**
# Create a class `MobilePhone` with a private variable `__pin`.
# Set `__pin = 1234` in `__init__`.
# Write a method `check_pin(entered_pin)` that checks if the entered pin matches the private pin.
# If it matches, print `'Access Granted'`. Otherwise, print `'Access Denied'`.
# Test it with a correct and an incorrect pin.
#
# **Hint:** Compare `entered_pin` with `self.__pin` inside the method.

# %%
# Write your code here
class MobilePhone:
    def __init__(self):
        self.__pin = 1234

    def check_pin(self, entered_pin):
        if entered_pin == self.__pin:
            print("Acess Granted")
        else:
            print("Acess Denied")

mobilephone = MobilePhone()


mobilephone.check_pin(5678)
mobilephone.check_pin(1234)
# Out:
# Acess Denied
# Acess Granted

# %% [markdown]
# ### Question 5
#
# **Problem Statement:**
# Create a class `Product` with private variables `__product_name` and `__price`.
# Write a setter method `set_price(new_price)` that updates the price.
# Write a getter method `get_price()` that returns the current price.
# Create an object, set an initial price, update it using the setter, and print the new price.
#
# **Hint:** A setter method allows controlled modification of a private variable.

# %%
# Write your code here
class Product:
    def __init__(self,product_name,price):
        self.__product_name = product_name
        self.__price = price

    def set_price(self, new_price):
        self.__price = new_price

    def get_price(self):
        return self.__price

product1 = Product("mobile","80000")
product1.set_price(50000)

print("updated price",product1.get_price())
# Out:
# updated price 50000

# %% [markdown]
# ### Question 6
#
# **Problem Statement:**
# Create a class `Student` with private variables `__name`, `__marks`.
# Write a method `display()` that prints the student name and marks in this format:
# `Student: Priya | Marks: 88`
# The display method should access the private variables internally.
# Create an object and call `display()`.
#
# **Hint:** Private variables can be accessed freely inside the class methods.

# %%
# Write your code here
class Student:
    def __init__(self, name, marks):
        self.__name = name
        self.__marks = marks

    def display(self):
        print("Student:", self.__name, "| Marks:", self.__marks)


# Create Object
student1 = Student("Priya", 88)

# Call display method
student1.display()
# Out:
# Student: Priya | Marks: 88

# %% [markdown]
# ### Question 7
#
# **Problem Statement:**
# Create a class `LoanAccount` with a private variable `__loan_amount`.
# Write a method `deposit(amount)` that reduces the loan amount by the given value.
# Write a method `get_loan_amount()` that returns the remaining loan.
# Start with a loan of `100000`, make two deposits of `20000` and `15000`, and print the remaining loan after each.
#
# **Hint:** Each call to `deposit()` should subtract from `self.__loan_amount`.

# %%
# Write your code here
class LoanAccount:
    def __init__(self, loan_amount):
        self.__loan_amount = loan_amount

    def deposit(self, amount):
        self.__loan_amount = self.__loan_amount - amount

    def get_loan_amount(self):
        return self.__loan_amount


# Create Object
loan = LoanAccount(100000)

# First Deposit
loan.deposit(20000)
print("Remaining Loan:", loan.get_loan_amount())

# Second Deposit
loan.deposit(15000)
print("Remaining Loan:", loan.get_loan_amount())
# Out:
# Remaining Loan: 80000
# Remaining Loan: 65000

# %% [markdown]
# ### Question 8
#
# **Problem Statement:**
# Create a class `UserProfile` with private variables `__username` and `__password`.
# Write a method `login(username, password)` that checks both values.
# If both match the stored private values, print `'Login successful'`.
# Otherwise, print `'Login failed'`.
# Test the method with correct and incorrect credentials.
#
# **Hint:** Store the correct username and password in `__init__` as private variables.

# %%
# Write your code here
class UserProfile:
    def __init__(self, username, password):
        self.__username = username
        self.__password = password

    def login(self, username, password):
        if self.__username == username and self.__password == password:
            print("Login successful")
        else:
            print("Login failed")


# Create Object
user1 = UserProfile("Priya", "abc123")

# Correct Credentials
user1.login("Priya", "abc123")

# Incorrect Credentials
user1.login("Priya", "xyz123")
# Out:
# Login successful
# Login failed

# %% [markdown]
# ---
#
# ## Section 2: Inheritance Practice
#
# Inheritance allows a child class to use the attributes and methods of a parent class.
# Use `class Child(Parent):` to create a child class.
# Use `super().__init__()` to call the parent class constructor.

# %% [markdown]
# ### Question 9
#
# **Problem Statement:**
# Create a parent class `Animal` with an attribute `name` and a method `eat()` that prints `'{name} is eating'`.
# Create a child class `Dog` that inherits from `Animal`.
# Add a method `bark()` in `Dog` that prints `'{name} is barking'`.
# Create a `Dog` object, call both `eat()` and `bark()`.
#
# **Hint:** The child class inherits all methods from the parent class automatically.

# %%
# Write your code here
class Animal:
    def __init__(self, name):
        self.name = name


class Dog(Animal):
    def __init__(self, name):
        Animal.__init__(self, name)

    def bark(self):
        print(self.name, "is barking")


dog1 = Dog("Tommy")
dog1.bark()
# Out:
# Tommy is barking

# %% [markdown]
# ### Question 10
#
# **Problem Statement:**
# Create a parent class `Person` with attributes `name` and `age`.
# Add a method `introduce()` that prints `'I am {name} and I am {age} years old'`.
# Create a child class `Student` that inherits from `Person`.
# Add an attribute `roll_number` in `Student`.
# Add a method `show_roll()` that prints `'Roll Number: {roll_number}'`.
# Create a `Student` object and call both `introduce()` and `show_roll()`.
#
# **Hint:** Use `super().__init__(name, age)` in the `Student` constructor.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"I am {self.name} and I am {self.age} years old")


class Student(Person):
    def __init__(self, name, age, roll_number):
        super().__init__(name, age)
        self.roll_number = roll_number

    def show_roll(self):
        print("Roll Number:", self.roll_number)


# Create Object
student1 = Student("Priya", 20, 101)

# Call Methods
student1.introduce()
student1.show_roll()
# Out:
# I am Priya and I am 20 years old
# Roll Number: 101

# %% [markdown]
# ### Question 11
#
# **Problem Statement:**
# Create a parent class `Vehicle` with attributes `brand` and `year`.
# Add a method `show_details()` that prints the brand and year.
# Create a child class `Car` that inherits from `Vehicle`.
# Add an attribute `num_doors` in `Car`.
# Override the `show_details()` method in `Car` to also print the number of doors.
# Create a `Car` object and call `show_details()`.
#
# **Hint:** When you define `show_details()` in the child class, it replaces the parent version.

# %%
# Write your code here
class Vehicle:
    def __init__(self, brand, year):
        self.brand = brand
        self.year = year

    def show_details(self):
        print("Brand:", self.brand, "| Year:", self.year)


class Car(Vehicle):
    def __init__(self, brand, year, num_doors):
        super().__init__(brand, year)
        self.num_doors = num_doors

    def show_details(self):
        print("Brand:", self.brand, "| Year:", self.year, "| Doors:", self.num_doors)


car1 = Car("Toyota", 2022, 4)
car1.show_details()
# Out:
# Brand: Toyota | Year: 2022 | Doors: 4

# %% [markdown]
# ### Question 12
#
# **Problem Statement:**
# Create a parent class `Shape` with a method `area()` that prints `'Area not defined'`.
# Create a child class `Rectangle` that inherits from `Shape`.
# Add attributes `length` and `width` in `Rectangle`.
# Override `area()` in `Rectangle` to calculate and print the correct area.
# Create a `Rectangle` object with length `5` and width `3` and call `area()`.
#
# **Hint:** Area of a rectangle = length x width.

# %%
# Write your code here
class Shape:
    def area(self):
        print("Area not defined")


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        print("Area:", self.length * self.width)


rect1 = Rectangle(5, 3)
rect1.area()
# Out:
# Area: 15

# %% [markdown]
# ### Question 13
#
# **Problem Statement:**
# Create a parent class `Employee` with attributes `name` and `salary`.
# Add a method `show_salary()` that prints `'{name} earns {salary}'`.
# Create a child class `Manager` that inherits from `Employee`.
# Add an attribute `department` in `Manager`.
# Add a method `show_department()` that prints `'{name} manages {department}'`.
# Create a `Manager` object and call both methods.
#
# **Hint:** Use `super().__init__(name, salary)` inside the Manager constructor.

# %%
# Write your code here
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def show_salary(self):
        print(f"{self.name} earns {self.salary}")


class Manager(Employee):
    def __init__(self, name, salary, department):
        super().__init__(name, salary)
        self.department = department

    def show_department(self):
        print(f"{self.name} manages {self.department}")


manager1 = Manager("Rahul", 90000, "Sales")
manager1.show_salary()
manager1.show_department()
# Out:
# Rahul earns 90000
# Rahul manages Sales

# %% [markdown]
# ### Question 14
#
# **Problem Statement:**
# Create a parent class `BankAccount` with attribute `balance` set to `10000`.
# Add methods `deposit(amount)` and `withdraw(amount)` that update the balance.
# Add a method `get_balance()` that returns the balance.
# Create a child class `SavingsAccount` that inherits from `BankAccount`.
# Add an attribute `interest_rate` in `SavingsAccount`.
# Add a method `add_interest()` that increases the balance by the interest rate percentage.
# Create a `SavingsAccount` object, deposit `5000`, add interest, and print the final balance.
#
# **Hint:** `add_interest()` should modify `self.balance` which is inherited from the parent.

# %%
# Write your code here
class BankAccount:
    def __init__(self):
        self.balance = 10000

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        self.balance -= amount

    def get_balance(self):
        return self.balance


class SavingsAccount(BankAccount):
    def __init__(self, interest_rate):
        super().__init__()
        self.interest_rate = interest_rate

    def add_interest(self):
        self.balance += self.balance * self.interest_rate / 100


account1 = SavingsAccount(5)
account1.deposit(5000)
account1.add_interest()
print("Final Balance:", account1.get_balance())
# Out:
# Final Balance: 15750.0

# %% [markdown]
# ### Question 15
#
# **Problem Statement:**
# Create a parent class `Phone` with attribute `brand` and a method `call(number)` that prints `'Calling {number} from {brand}'`.
# Create a child class `Smartphone` that inherits from `Phone`.
# Add a method `browse(website)` that prints `'Browsing {website} on {brand}'`.
# Create a `Smartphone` object and call both `call()` and `browse()`.
#
# **Hint:** The child class inherits the `call()` method without you needing to rewrite it.

# %%
# Write your code here
class Phone:
    def __init__(self, brand):
        self.brand = brand

    def call(self, number):
        print(f"Calling {number} from {self.brand}")


class Smartphone(Phone):
    def browse(self, website):
        print(f"Browsing {website} on {self.brand}")


phone1 = Smartphone("Samsung")
phone1.call("9876543210")
phone1.browse("google.com")
# Out:
# Calling 9876543210 from Samsung
# Browsing google.com on Samsung

# %% [markdown]
# ### Question 16
#
# **Problem Statement:**
# Create a parent class `LibraryItem` with attribute `title` and a method `show_title()` that prints the title.
# Create a child class `Book` that inherits from `LibraryItem`.
# Add attributes `author` and `pages` in `Book`.
# Add a method `show_book_details()` that prints title, author, and number of pages.
# Create a `Book` object and call both `show_title()` and `show_book_details()`.
#
# **Hint:** `show_title()` is inherited from the parent and does not need to be rewritten.

# %%
# Write your code here
class LibraryItem:
    def __init__(self, title):
        self.title = title

    def show_title(self):
        print("Title:", self.title)


class Book(LibraryItem):
    def __init__(self, title, author, pages):
        super().__init__(title)
        self.author = author
        self.pages = pages

    def show_book_details(self):
        print("Title:", self.title, "| Author:", self.author, "| Pages:", self.pages)


book1 = Book("The Alchemist", "Paulo Coelho", 208)
book1.show_title()
book1.show_book_details()
# Out:
# Title: The Alchemist
# Title: The Alchemist | Author: Paulo Coelho | Pages: 208

# %% [markdown]
# ---
#
# ## Section 3: Polymorphism Practice
#
# Polymorphism means the same method name can work differently for different classes.
# You can define a method with the same name in multiple classes.
# Each class gives its own implementation of that method.

# %% [markdown]
# ### Question 17
#
# **Problem Statement:**
# Create two classes: `Dog` and `Cat`.
# Both classes should have a method named `sound()`.
# `Dog.sound()` should print `'Dog says: Woof'`.
# `Cat.sound()` should print `'Cat says: Meow'`.
# Create one object of each class and call `sound()` on both.
#
# **Hint:** Same method name, different output — this is polymorphism.

# %%
# Write your code here
class Dog:
    def sound(self):
        print("Dog says: Woof")


class Cat:
    def sound(self):
        print("Cat says: Meow")


dog1 = Dog()
cat1 = Cat()

dog1.sound()
cat1.sound()
# Out:
# Dog says: Woof
# Cat says: Meow

# %% [markdown]
# ### Question 18
#
# **Problem Statement:**
# Create three classes: `Circle`, `Rectangle`, and `Triangle`.
# All three should have a method named `area()`.
# Each class should accept the required dimensions in `__init__` and calculate the area in `area()`.
# Create one object of each class and call `area()` on all three.
#
# **Hint:** Circle area = 3.14 x r x r | Rectangle area = l x w | Triangle area = 0.5 x b x h.

# %%
# Write your code here
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Circle Area:", 3.14 * self.radius * self.radius)


class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        print("Rectangle Area:", self.length * self.width)


class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        print("Triangle Area:", 0.5 * self.base * self.height)


circle1 = Circle(5)
rectangle1 = Rectangle(4, 6)
triangle1 = Triangle(8, 3)

circle1.area()
rectangle1.area()
triangle1.area()
# Out:
# Circle Area: 78.5
# Rectangle Area: 24
# Triangle Area: 12.0

# %% [markdown]
# ### Question 19
#
# **Problem Statement:**
# Create a parent class `Vehicle` with a method `fuel_type()` that prints `'Fuel type not specified'`.
# Create two child classes: `PetrolCar` and `ElectricCar`.
# Override `fuel_type()` in `PetrolCar` to print `'This car runs on Petrol'`.
# Override `fuel_type()` in `ElectricCar` to print `'This car runs on Electricity'`.
# Create one object of each child class and call `fuel_type()`.
#
# **Hint:** Method overriding means redefining a parent method in the child class.

# %%
# Write your code here
class Vehicle:
    def fuel_type(self):
        print("Fuel type not specified")


class PetrolCar(Vehicle):
    def fuel_type(self):
        print("This car runs on Petrol")


class ElectricCar(Vehicle):
    def fuel_type(self):
        print("This car runs on Electricity")


petrol_car1 = PetrolCar()
electric_car1 = ElectricCar()

petrol_car1.fuel_type()
electric_car1.fuel_type()
# Out:
# This car runs on Petrol
# This car runs on Electricity

# %% [markdown]
# ### Question 20
#
# **Problem Statement:**
# Create a parent class `Employee` with a method `work()` that prints `'Employee is working'`.
# Create two child classes: `Developer` and `Designer`.
# Override `work()` in `Developer` to print `'Developer is writing code'`.
# Override `work()` in `Designer` to print `'Designer is creating UI'`.
# Create a list containing one object of each class.
# Loop through the list and call `work()` on each object.
#
# **Hint:** Calling the same method on different objects produces different results.

# %%
# Write your code here
class Employee:
    def work(self):
        print("Employee is working")


class Developer(Employee):
    def work(self):
        print("Developer is writing code")


class Designer(Employee):
    def work(self):
        print("Designer is creating UI")


employees = [Developer(), Designer()]

for employee in employees:
    employee.work()
# Out:
# Developer is writing code
# Designer is creating UI

# %% [markdown]
# ### Question 21
#
# **Problem Statement:**
# Create two classes: `IndianFood` and `ItalianFood`.
# Both should have a method `describe()` that prints a short description of that cuisine.
# Create one object of each and call `describe()`.
# Then write a separate function `introduce_food(food_object)` that accepts any food object and calls its `describe()` method.
# Call `introduce_food()` with both objects.
#
# **Hint:** The function does not know which class it receives — it just calls `describe()`.

# %%
# Write your code here
class IndianFood:
    def describe(self):
        print("Indian food is known for its rich spices and diverse flavors.")


class ItalianFood:
    def describe(self):
        print("Italian food is known for pasta, pizza, and fresh herbs.")


def introduce_food(food_object):
    food_object.describe()


indian1 = IndianFood()
italian1 = ItalianFood()

introduce_food(indian1)
introduce_food(italian1)
# Out:
# Indian food is known for its rich spices and diverse flavors.
# Italian food is known for pasta, pizza, and fresh herbs.

# %% [markdown]
# ### Question 22
#
# **Problem Statement:**
# Create a parent class `Notification` with a method `send()` that prints `'Sending notification'`.
# Create three child classes: `EmailNotification`, `SMSNotification`, and `PushNotification`.
# Override `send()` in each child class to print a specific message:
# - `EmailNotification`: `'Sending Email notification'`
# - `SMSNotification`: `'Sending SMS notification'`
# - `PushNotification`: `'Sending Push notification'`
# Create one object of each child class and call `send()` on all three.
#
# **Hint:** Each child overrides the same method with its own implementation.

# %%
# Write your code here
class Notification:
    def send(self):
        print("Sending notification")


class EmailNotification(Notification):
    def send(self):
        print("Sending Email notification")


class SMSNotification(Notification):
    def send(self):
        print("Sending SMS notification")


class PushNotification(Notification):
    def send(self):
        print("Sending Push notification")


email1 = EmailNotification()
sms1 = SMSNotification()
push1 = PushNotification()

email1.send()
sms1.send()
push1.send()
# Out:
# Sending Email notification
# Sending SMS notification
# Sending Push notification

# %% [markdown]
# ### Question 23
#
# **Problem Statement:**
# Create two classes: `KiloMeter` and `Mile`.
# Both should have a method `convert()` that converts the stored distance value:
# - `KiloMeter.convert()` converts km to miles: `km x 0.621`
# - `Mile.convert()` converts miles to km: `miles x 1.609`
# Accept the distance value in `__init__`.
# Create one object of each class and call `convert()` on both. Print the result.
#
# **Hint:** Same method name, same purpose, different formula.

# %%
# Write your code here
class KiloMeter:
    def __init__(self, distance):
        self.distance = distance

    def convert(self):
        return self.distance * 0.621


class Mile:
    def __init__(self, distance):
        self.distance = distance

    def convert(self):
        return self.distance * 1.609


km1 = KiloMeter(10)
mile1 = Mile(10)

print("Kilometers to Miles:", km1.convert())
print("Miles to Kilometers:", mile1.convert())
# Out:
# Kilometers to Miles: 6.21
# Miles to Kilometers: 16.09

# %% [markdown]
# ---
#
# ## Section 4: Abstraction Practice
#
# Abstraction means hiding internal implementation details from the user.
# The user calls a simple public method without knowing what happens inside.
# Private methods (using `__`) are used to hide internal steps.

# %% [markdown]
# ### Question 24
#
# **Problem Statement:**
# Create a class `Car` with a private method `__start_engine()` that prints `'Engine started'`.
# Create a public method `start()` that calls `__start_engine()` internally and then prints `'Car is ready to drive'`.
# Create a `Car` object and call only `start()`.
#
# **Hint:** The user calls `start()`. They do not need to know about `__start_engine()`.

# %%
# Write your code here
class Car:
    def __start_engine(self):
        print("Engine started")

    def start(self):
        self.__start_engine()
        print("Car is ready to drive")


car1 = Car()
car1.start()
# Out:
# Engine started
# Car is ready to drive

# %% [markdown]
# ### Question 25
#
# **Problem Statement:**
# Create a class `CoffeeMachine` with the following private methods:
# - `__heat_water()` that prints `'Heating water'`
# - `__grind_beans()` that prints `'Grinding coffee beans'`
# - `__pour_coffee()` that prints `'Pouring coffee into cup'`
#
# Create a public method `make_coffee()` that calls all three private methods in order.
# Create a `CoffeeMachine` object and call only `make_coffee()`.
#
# **Hint:** The user only sees `make_coffee()`. All internal steps are hidden.

# %%
# Write your code here
class CoffeeMachine:
    def __heat_water(self):
        print("Heating water")

    def __grind_beans(self):
        print("Grinding coffee beans")

    def __pour_coffee(self):
        print("Pouring coffee into cup")

    def make_coffee(self):
        self.__heat_water()
        self.__grind_beans()
        self.__pour_coffee()


coffee_machine1 = CoffeeMachine()
coffee_machine1.make_coffee()
# Out:
# Heating water
# Grinding coffee beans
# Pouring coffee into cup

# %% [markdown]
# ### Question 26
#
# **Problem Statement:**
# Create a class `ATM` with the following private methods:
# - `__verify_pin()` that prints `'PIN verified'`
# - `__check_balance()` that prints `'Balance checked'`
# - `__dispense_cash()` that prints `'Cash dispensed'`
#
# Create a public method `withdraw()` that calls all three private methods in order.
# Create an `ATM` object and call `withdraw()`.
#
# **Hint:** A real ATM hides all its internal steps from the user.

# %%
# Write your code here
class ATM:
    def __verify_pin(self):
        print("PIN verified")

    def __check_balance(self):
        print("Balance checked")

    def __dispense_cash(self):
        print("Cash dispensed")

    def withdraw(self):
        self.__verify_pin()
        self.__check_balance()
        self.__dispense_cash()


atm1 = ATM()
atm1.withdraw()
# Out:
# PIN verified
# Balance checked
# Cash dispensed

# %% [markdown]
# ### Question 27
#
# **Problem Statement:**
# Create a class `EmailSender` with:
# - A private method `__connect_to_server()` that prints `'Connecting to mail server'`
# - A private method `__authenticate()` that prints `'Authenticating credentials'`
# - A private method `__compose_email()` that prints `'Composing email'`
# - A public method `send_email(recipient)` that calls all three private methods and then prints `'Email sent to {recipient}'`
#
# Create an `EmailSender` object and call `send_email('priya@example.com')`.
#
# **Hint:** The recipient only sees that the email was sent, not how it was processed internally.

# %%
# Write your code here
class EmailSender:
    def __connect_to_server(self):
        print("Connecting to mail server")

    def __authenticate(self):
        print("Authenticating credentials")

    def __compose_email(self):
        print("Composing email")

    def send_email(self, recipient):
        self.__connect_to_server()
        self.__authenticate()
        self.__compose_email()
        print(f"Email sent to {recipient}")


email_sender1 = EmailSender()
email_sender1.send_email("priya@example.com")
# Out:
# Connecting to mail server
# Authenticating credentials
# Composing email
# Email sent to priya@example.com

# %% [markdown]
# ### Question 28
#
# **Problem Statement:**
# Create a class `OnlinePayment` with:
# - A private method `__validate_card()` that prints `'Card validated'`
# - A private method `__check_funds()` that prints `'Funds checked'`
# - A public method `pay(amount)` that calls both private methods and then prints `'Payment of {amount} successful'`
#
# Create an `OnlinePayment` object and call `pay(2500)`.
#
# **Hint:** Abstract away the card validation and fund check behind the `pay()` method.

# %%
# Write your code here
class OnlinePayment:
    def __validate_card(self):
        print("Card validated")

    def __check_funds(self):
        print("Funds checked")

    def pay(self, amount):
        self.__validate_card()
        self.__check_funds()
        print(f"Payment of {amount} successful")


payment1 = OnlinePayment()
payment1.pay(2500)
# Out:
# Card validated
# Funds checked
# Payment of 2500 successful

# %% [markdown]
# ### Question 29
#
# **Problem Statement:**
# Create a class `MusicPlayer` with:
# - A private variable `__volume` set to `50`
# - A private method `__load_file(song)` that prints `'Loading: {song}'`
# - A private method `__decode_audio()` that prints `'Decoding audio file'`
# - A public method `play(song)` that calls `__load_file(song)`, then `__decode_audio()`, and finally prints `'Now playing: {song} at volume {volume}'`
#
# Create a `MusicPlayer` object and call `play('Kesariya')`.
#
# **Hint:** `play()` is the only method the user interacts with. All internal steps are hidden.

# %%
# Write your code here
class MusicPlayer:
    def __init__(self):
        self.__volume = 50

    def __load_file(self, song):
        print(f"Loading: {song}")

    def __decode_audio(self):
        print("Decoding audio file")

    def play(self, song):
        self.__load_file(song)
        self.__decode_audio()
        print(f"Now playing: {song} at volume {self.__volume}")


player1 = MusicPlayer()
player1.play("Kesariya")
# Out:
# Loading: Kesariya
# Decoding audio file
# Now playing: Kesariya at volume 50

# %% [markdown]
# ### Question 30
#
# **Problem Statement:**
# Create a class `DeliverySystem` with:
# - A private method `__assign_driver()` that prints `'Driver assigned'`
# - A private method `__calculate_route()` that prints `'Route calculated'`
# - A private method `__notify_customer()` that prints `'Customer notified'`
# - A public method `place_order(item, address)` that calls all three private methods in order and then prints `'Order for {item} is on its way to {address}'`
#
# Create a `DeliverySystem` object and call `place_order('Laptop', 'MG Road, Bangalore')`.
#
# **Hint:** Think of this like Swiggy or Zomato — the customer places an order and the internal processing is hidden.

# %%
# Write your code here
class DeliverySystem:
    def __assign_driver(self):
        print("Driver assigned")

    def __calculate_route(self):
        print("Route calculated")

    def __notify_customer(self):
        print("Customer notified")

    def place_order(self, item, address):
        self.__assign_driver()
        self.__calculate_route()
        self.__notify_customer()
        print(f"Order for {item} is on its way to {address}")


delivery1 = DeliverySystem()
delivery1.place_order("Laptop", "MG Road, Bangalore")
# Out:
# Driver assigned
# Route calculated
# Customer notified
# Order for Laptop is on its way to MG Road, Bangalore
